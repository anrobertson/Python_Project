# %%
from faker import Faker     
import numpy as np
import pandas as pd

# Creating fake companies
companies= ['Hershe','Campbull','Costgo','Walsmart','Procter & Deal','Kroft','General Malls','Betty Socker','Chiquota','Nosson Foods','Del Marte','Folders']

fake = Faker() 

def generate_fake_address():
    full_address = fake.address()
    
    # Remove the zip code, state, and city from the address
    parts = full_address.split('\n')
    address_line1 = parts[0]
    address_line2 = '\n'.join(parts[1:])
    
    return address_line1, address_line2

def create_data(x): 
    b_user = {} 
    for i in range(x): 
        b_user[i] = {} 
        b_user[i]['UMI'] = fake.random_int(min=2030000000000, max=2039999999999)
        b_user[i]['Sender Level2'] = fake.random_int(min=4000000000, max=4000999999)
        b_user[i]['Sender Level2 Name'] = fake.random_element(companies)
        b_user[i]['Sender Level1'] = fake.random_int(min=4000000000, max=4000999999)
        b_user[i]['Sender Level1 Name'] = fake.company()
        b_user[i]['Sender'] = fake.random_int(min=4000000000, max=4000999999)
        b_user[i]['Sender Name'] = fake.company()
        b_user[i]['Sender Ext Code'] = fake.random_int(min=4000234512, max=79999999999)
        b_user[i]['Sender GLID City'] = fake.city()
        b_user[i]['Sender Audit Date'] = fake.date_this_year()
        b_user[i]['Sender Channel'] = 'Emitter'
        b_user[i]['Sender_Owner'] = fake.name()
        b_user[i]['Sender Account Executive'] = '-'
        b_user[i]['Mvmt Receiver Name'] = fake.company()
        
        # Generate fake address without zip code, state, or city
        address_line1, _ = generate_fake_address()  # Remove the unused address_line2
        b_user[i]['Mvmt Receiver Address'] = address_line1
        
        state = fake.state()
        city = fake.city()
        zipcode = fake.postcode()
        
        b_user[i]['Mvmt Receiver City'] = city
        b_user[i]['Mvmt Receiver Region'] = state
        b_user[i]['Mvmt Receiver Zipcode'] = zipcode
        
        b_user[i]['DOD'] = fake.date_this_year()
        b_user[i]['Unk_DON'] = fake.date_this_year()
        b_user[i]['Qty'] = fake.random_int(min=1, max=40)
        
        # Generate numbers in the format of "10-20," "30-40," etc. for the age bucket
        lower_bound = fake.random_int(min=1, max=9) * 10
        upper_bound = lower_bound + 10
        b_user[i]['Age Bucket'] = f"{lower_bound}-{upper_bound}"    
        
    return b_user
    
df = pd.DataFrame(create_data(40)).transpose()
df.head(5)
# Out:
#              UMI Sender Level2 Sender Level2 Name Sender Level1  \
# 0  2032597156537    4000472075             Hershe    4000714054
# 1  2034793920302    4000925173       Betty Socker    4000135386
# 2  2031383084122    4000922889           Chiquota    4000263419
# 3  2033781058363    4000159975             Hershe    4000768519
# 4  2035306621161    4000820021            Folders    4000867677
#
#          Sender Level1 Name      Sender     Sender Name Sender Ext Code  \
# 0            Clark-Gonzalez  4000829408  Robinson Group     28891216826
# 1  Kim, Roberts and Barnett  4000265860     Jackson LLC     18245146357
# 2           Warner-Garrison  4000602847       Kelly Inc     34485389336
# 3                Clarke LLC  4000369794    Gardner-Mays     18419854564
# 4             Delgado-Young  4000274868        Pugh LLC     79228527901
#
#       Sender GLID City Sender Audit Date  ... Sender Account Executive  \
# 0         Kaylaborough        2023-07-08  ...                        -
# 1       New Robertview        2023-03-26  ...                        -
# 2  South Stephanieport        2023-06-24  ...                        -
# 3          Ryanchester        2023-06-16  ...                        -
# 4           Olsonmouth        2023-08-12  ...                        -
#
#             Mvmt Receiver Name        Mvmt Receiver Address  \
# 0               Thompson Group             30344 Luna Falls
# 1                 White-Nguyen           PSC 1172, Box 0382
# 2       White, Hardy and Mills  2536 Contreras Way Apt. 692
# 3  Taylor, Erickson and Ramsey            93617 Jody Rapids
# 4                  Mayo-Walker     566 Seth Branch Apt. 857
#
#   Mvmt Receiver City Mvmt Receiver Region Mvmt Receiver Zipcode         DOD  \
# 0    Port Danielfort             Oklahoma                 29046  2023-07-05
# 1         Chavezbury         Pennsylvania                 34325  2023-09-08
# 2         Garciaberg              Wyoming                 60084  2023-01-24
# 3       West Jonport            Louisiana                 78646  2023-10-11
# 4        Teresaburgh         North Dakota                 31388  2023-05-03
#
#       Unk_DON Qty Age Bucket
# 0  2023-05-23   5      40-50
# 1  2023-02-22   3      50-60
# 2  2023-04-27  29      20-30
# 3  2023-05-30  30     90-100
# 4  2023-05-02  31      70-80
#
# [5 rows x 22 columns]
